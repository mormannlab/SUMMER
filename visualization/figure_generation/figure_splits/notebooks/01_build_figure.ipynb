# %% [markdown]
# # fig 1: dataset and stimulus overview
#
#
# #### Purpose: Give readers enough information about the dataset as a glance to decide if it is of interest to them.

# %%
import time
import IPython.display as IPd

import time
import sys
import os
from copy import deepcopy
from pathlib import Path

import time
import IPython.display as IPd
import matplotlib as mpl
import matplotlib.pylab as plt
import numpy as np
import pandas as pd
def svg(img):
    IPd.display(IPd.HTML('{}" / >'.format(img, time.time())))

from svgutils.compose import *

import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', )))
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', '..', '..',)))
from plot_code.config_plot_params import *

# %%
svg_scale = 1.25  # set this to 1.25 for Inkscape, 1.0 otherwise

# Panel letters in Helvetica Neue, 12pt, Medium
kwargs_text = {'size': '17pt', 'font': 'Helvetica', 'weight': '800'}

f = Figure("20cm", "15cm",
        
    Panel(
        Image(650, 300, "../svg/cv.png"),
        Text("a", -10, 15, **kwargs_text),
    ).move(30, 20),

    Panel(
        Image(650, 230, "../svg/buffer_lengths.jpg"),
        Text("b", -10, 0, **kwargs_text),
    ).move(30, 330),
)

f.save("../fig/fig_splits.svg")
svg("../fig/fig_splits.svg")
