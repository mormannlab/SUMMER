# %% [markdown]
# # data overview figure

# %%
import time
import sys
import os
from copy import deepcopy
from pathlib import Path

import time
import IPython.display as IPd
import matplotlib as mpl
import matplotlib.pylab as plt
import numpy as np
import pandas as pd

# %%
import time
import IPython.display as IPd

def svg(img):
    IPd.display(IPd.HTML('{}" / >'.format(img, time.time())))

# %%
from svgutils.compose import *

# > Inkscape pixel is 1/90 of an inch, other software usually uses 1/72.
# > http://www.inkscapeforum.com/viewtopic.php?f=6&t=5964
svg_scale = 1.25  # set this to 1.25 for Inkscape, 1.0 otherwise

# Panel letters in Helvetica Neue, 12pt, Medium
kwargs_text = {'size': '12pt', 'font': 'Arial', 'weight': '800'}


f = Figure("16.5cm", "13cm",
           
      Panel(
          SVG("../svg/concept.svg").scale(0.5),
          Text("b", -15, 0, **kwargs_text),
    ).move(20, 20),

    Panel(
          SVG("../svg/text.svg").scale(0.5),
          Text("c", -15, 0, **kwargs_text),
    ).move(220, 20),
           
      Panel(
          SVG("../svg/complete.svg").scale(1.0),
          Text("a", -15, -50, **kwargs_text),
    ).move(20, 230),

    Panel(
          SVG("../svg/transitions.svg").scale(0.5),
          Text("d", -15, 0, **kwargs_text),
    ).move(420, 20),

    Panel(
          SVG("../svg/audio.svg").scale(0.5),
          Text("e", -15, 0, **kwargs_text),
    ).move(420, 140),

    Panel(
          SVG("../svg/box.svg").scale(0.5),
          Text("f", -15, 0, **kwargs_text),
    ).move(420, 260), 

    Panel(
          SVG("../svg/mask.svg").scale(0.5),
          Text("g", -15, 0, **kwargs_text),
    ).move(420, 380), 
           
)

f.save("../fig/fig_annotations.svg")
svg("../fig/fig_annotations.svg")
# Out:
# ../fig/fig_annotations.svg" / >
