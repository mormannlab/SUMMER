# %%
# Connect to DHV database
import sys
sys.path.append('/usr/wiss/gerkenf/DHV/epiphyte_tube')
from database.db_setup import *
print(f'Connection Status: {dj.conn()}')
# Out:
# Epiphyte Tube version loaded.
# Connecting fgerken@134.2.168.111:3306
# Connection Status: DataJoint connection (connected) fgerken@134.2.168.111:3306

# %%
MovieAnnotation()
# Out:
# *label_name    *annotation_da *annotator_id  values     start_time stop_times category       indicator_
# +------------+ +------------+ +------------+ +--------+ +--------+ +--------+ +------------+ +--------+
# alison         2021-03-29     p1             =BLOB=     =BLOB=     =BLOB=     character      =BLOB=
# autumn         2021-03-29     p1             =BLOB=     =BLOB=     =BLOB=     character      =BLOB=
# beach          2022-08-08     p1             =BLOB=     =BLOB=     =BLOB=     location       =BLOB=
# bed            2024-01-24     p2             =BLOB=     =BLOB=     =BLOB=     segmentation   =BLOB=
# bench          2024-01-24     p2             =BLOB=     =BLOB=     =BLOB=     segmentation   =BLOB=
# book           2024-01-24     p2             =BLOB=     =BLOB=     =BLOB=     segmentation   =BLOB=
# bottle         2024-01-24     p2             =BLOB=     =BLOB=     =BLOB=     segmentation   =BLOB=
# ...
