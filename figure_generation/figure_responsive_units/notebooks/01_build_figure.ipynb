# %% [markdown]
# # fig: responsive units

# %%
import time
import IPython.display as IPd

import time
import sys
import os
from copy import deepcopy
from pathlib import Path

import time
import IPython.display as IPd
import matplotlib as mpl
import matplotlib.pylab as plt
import numpy as np
import pandas as pd
def svg(img):
    IPd.display(IPd.HTML('{}" / >'.format(img, time.time())))

from svgutils.compose import *

import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', )))
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', '..', '..',)))
from plot_code.config_plot_params import *
# Out:
# Loaded font name: Helvetica

# %%
svg_scale = 1.25  # set this to 1.25 for Inkscape, 1.0 otherwise

# Panel letters in Helvetica Neue, 12pt, Medium
kwargs_text = {'size': '20pt', 'font': 'Helvetica', 'weight': '800'}

f = Figure("23cm", "9.5cm",
        
    Panel(
        SVG("../svg/camera-cuts_pat68_unit82_PHC_key1.svg").scale(0.4),
        Text("a", 5, 30, **kwargs_text),
    ).move(0, 0),

    Panel(
        SVG("../svg/camera-cuts_pat68_unit33_PHC_key1.svg").scale(0.4),
        #Text("", 5, 15, **kwargs_text),
    ).move(220, 0),

    Panel(
        SVG("../svg/camera-cuts_pat31_unit53_PHC_key1.svg").scale(0.4),
        #Text("", 5, 15, **kwargs_text),
    ).move(395, 0),

    Panel(
        SVG("../svg/camera-cuts_PHC_key1.svg").scale(0.4),
        Text("b", 0, 30, **kwargs_text),
    ).move(580, 0),
)

f.save("../fig/fig_responsive_units.svg")
svg("../fig/fig_responsive_units.svg")
# Out:
# ../fig/fig_responsive_units.svg" / >
