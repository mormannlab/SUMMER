# %% [markdown]
# # fig 1: dataset and stimulus overview
#
#
# #### Purpose: Give readers enough information about the dataset as a glance to decide if it is of interest to them.

# %%
import time
import IPython.display as IPd

import time
import sys
import os
from copy import deepcopy
from pathlib import Path

import time
import IPython.display as IPd
import matplotlib as mpl
import matplotlib.pylab as plt
import numpy as np
import pandas as pd
def svg(img):
    IPd.display(IPd.HTML('{}" / >'.format(img, time.time())))

from svgutils.compose import *

import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', )))
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', '..', '..',)))
from plot_code.config_plot_params import *

# %%
svg_scale = 1.25  # set this to 1.25 for Inkscape, 1.0 otherwise

# Panel letters in Helvetica Neue, 12pt, Medium
kwargs_text = {'size': '20pt', 'font': 'Helvetica', 'weight': '800'}

f = Figure("19cm", "21cm",
        
    Panel(
        Image(2385, 1059, "../svg/raster.png").scale(0.29),
    ).move(0, 70),

    Panel(
        Image(1948, 189, "../svg/frames.png").scale(0.314),
        Text("a", -30, 3, **kwargs_text),
    ).move(40, 20),

    Panel(
        SVG("../svg/localizations.svg").scale(1.0),
        Text("b", -15, 10, **kwargs_text),
    ).move(30, 375),
    
    Panel(
        SVG("../svg/units_by_region.svg").scale(0.8),
        Text("c", 10, 0, **kwargs_text),
    ).move(10, 578),

    Panel(
        SVG("../svg/unit_distribution_across_patients.svg").scale(0.8),
        Text("d", -15, 10, **kwargs_text),
    ).move(235, 570),
)

f.save("../fig/fig_data_overview.svg")
svg("../fig/fig_data_overview.svg")
# Out:
# ../fig/fig_data_overview.svg" / >
